# %% [markdown]
# # Nifty50 Closing Price Prediction using ML
#
# * Model: Stacked LSTM
# * Dataset: Nifty50 from Yahoo Fianance

# %% [markdown]
# ## Initialization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./dataset/NIFTY50.csv')
df.index = pd.to_datetime(df['Date']).dt.date

df.drop(['Date', 'Adj Close'], axis='columns', inplace=True)
display(df.head())
display(df.tail())
# Out:
#                    Open         High          Low        Close
# Date
# 2007-09-17  4518.450195  4549.049805  4482.850098  4494.649902
# 2007-09-18  4494.100098  4551.799805  4481.549805  4546.200195
# 2007-09-19  4550.250000  4739.000000  4550.250000  4732.350098
# 2007-09-20  4734.850098  4760.850098  4721.149902  4747.549805
# 2007-09-21  4752.950195  4855.700195  4733.700195  4837.549805
#                    Open         High          Low        Close
# Date
# 2021-04-26  14449.45020  14557.50000  14421.29981  14485.00000
# 2021-04-27  14493.79981  14667.54981  14484.84961  14653.04981
# 2021-04-28  14710.50000  14890.25000  14694.95020  14864.54981
# 2021-04-29  14979.00000  15044.34961  14814.45020  14894.90039
# 2021-04-30  14747.34961  14855.45020  14601.70020  14631.09961

# %%
print(f'Dataset Shape: {df.shape}\n')
display(df.info())
# Out:
# Dataset Shape: (3326, 4)
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 3326 entries, 2007-09-17 to 2021-04-30
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    3326 non-null   float64
#  1   High    3326 non-null   float64
#  2   Low     3326 non-null   float64
#  3   Close   3326 non-null   float64
# dtypes: float64(4)
# memory usage: 129.9+ KB
# None

# %%
window_len = 5
feature = 'Open'

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, test_size=0.2, shuffle=False)

# %%
df_train.head()
# Out:
#                    Open         High          Low        Close
# Date
# 2007-09-17  4518.450195  4549.049805  4482.850098  4494.649902
# 2007-09-18  4494.100098  4551.799805  4481.549805  4546.200195
# 2007-09-19  4550.250000  4739.000000  4550.250000  4732.350098
# 2007-09-20  4734.850098  4760.850098  4721.149902  4747.549805
# 2007-09-21  4752.950195  4855.700195  4733.700195  4837.549805

# %%
df_test.head()
# Out:
#                    Open         High          Low       Close
# Date
# 2018-08-07  11423.15039  11428.95020  11359.70020  11389.4502
# 2018-08-08  11412.50000  11459.95020  11379.29981  11450.0000
# 2018-08-09  11493.25000  11495.20020  11454.09961  11470.7002
# 2018-08-10  11474.95020  11478.75000  11419.65039  11429.5000
# 2018-08-13  11369.59961  11406.29981  11340.29981  11355.7500

# %% [markdown]
# ## Plotting Closing Prices

# %%
fig, ax = plt.subplots(figsize=(23, 6))
ax.plot(df_train[feature], label='Train')
ax.plot(df_test[feature], label='Test')
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Closing Price (INR)', fontsize=12)
ax.set_title('Closing Price of Nifty50', fontsize=16)
ax.legend(fontsize=12)

# %% [markdown]
# ## Data Preprocessing

# %%
train = np.array(df_train[feature]).reshape(-1, 1)
test  = np.array(df_test [feature]).reshape(-1, 1)

# %% [markdown]
# ### Imputation
#
# * Needed if null values present

# %%
print(f'Null value count:\n{df.isnull().sum()}')
# Out:
# Null value count:
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(train)

train_sc = scaler.transform(train)
test_sc  = scaler.transform(test )

print(f'Scaled Training Set Example:', train_sc[0])
print(f'Scaled Testing  Set Example:', test_sc [0])
# Out:
# Scaled Training Set Example: [0.22206966]
# Scaled Testing  Set Example: [1.00244695]

# %%
def to_time_windows(data, window_len):
    windows = []
    for i in range(len(data) - window_len):
        windows.append(data[i:i+window_len])
    return np.array(windows)

X_train_sc = to_time_windows(train_sc, window_len)
X_test_sc  = to_time_windows(test_sc , window_len)

y_train_sc = train_sc[window_len:]
y_test_sc  = test_sc [window_len:]

y_train = scaler.inverse_transform(y_train_sc)
y_test  = scaler.inverse_transform(y_test_sc)

# %% [markdown]
# ## Building the Recurrent Neural Network

# %% [markdown]
# ### Setup Keras

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Activation, Dense, Dropout, LSTM
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %% [markdown]
# ### Initialising the RNN

# %%
def build_model(data, window_len):
    model = Sequential()
    
    # Layer 1, shape = (window length, no of features)
    model.add(LSTM(units=50, return_sequences=True, input_shape=(window_len, len(data[0][0]))))
    model.add(Dropout(0.2))
    
    # Layer 2
    model.add(LSTM(units=50))
    model.add(Dropout(0.2))
    
    # Output Layer
    model.add(Dense(units=1))
    model.add(Activation('relu'))
    
    model.compile(optimizer='adam', loss='mean_squared_error')
    
    display(model.summary())
    return model

model = build_model(X_train_sc, window_len)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 5, 50)             10400
# _________________________________________________________________
# dropout (Dropout)            (None, 5, 50)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Fitting the RNN to training set

# %%
model.fit(X_train_sc, y_train_sc, epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 6s 12ms/step - loss: 0.2666
# Epoch 2/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.2564
# Epoch 3/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.2525
# Epoch 4/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.2670
# Epoch 5/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.2680
# Epoch 6/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.2685
# Epoch 7/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.2642
# Epoch 8/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.2597
# Epoch 9/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.2676
# Epoch 10/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.2664
# Epoch 11/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.2620
# Epoch 12/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1461
# Epoch 13/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0032
# Epoch 14/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0024
# Epoch 15/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0022
# Epoch 16/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0020
# Epoch 17/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0018
# Epoch 18/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0018
# Epoch 19/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0018
# Epoch 20/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0016
# Epoch 21/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0018
# Epoch 22/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 23/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0016
# Epoch 24/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 25/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 26/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 27/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 28/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 29/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 30/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 31/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 32/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0015
# Epoch 33/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 34/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 35/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 36/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 37/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 38/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 39/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 40/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 41/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 42/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 43/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 44/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 45/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 46/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 47/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0011
# Epoch 48/100
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 49/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 50/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 51/100
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 52/100
# 42/42 [==============================] - 0s 9ms/step - loss: 9.5996e-04
# Epoch 53/100
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0010
# Epoch 54/100
# 42/42 [==============================] - 0s 10ms/step - loss: 8.8259e-04
# Epoch 55/100
# 42/42 [==============================] - 0s 10ms/step - loss: 9.2889e-04
# Epoch 56/100
# 42/42 [==============================] - 0s 10ms/step - loss: 8.6350e-04
# Epoch 57/100
# 42/42 [==============================] - 0s 10ms/step - loss: 9.4448e-04
# Epoch 58/100
# 42/42 [==============================] - 0s 11ms/step - loss: 9.3302e-04
# Epoch 59/100
# 42/42 [==============================] - 0s 10ms/step - loss: 9.0216e-04
# Epoch 60/100
# 42/42 [==============================] - 0s 9ms/step - loss: 8.6303e-04
# Epoch 61/100
# 42/42 [==============================] - 0s 10ms/step - loss: 8.8041e-04
# Epoch 62/100
# 42/42 [==============================] - 0s 10ms/step - loss: 8.7776e-04
# Epoch 63/100
# 42/42 [==============================] - 0s 10ms/step - loss: 8.8031e-04
# Epoch 64/100
# 42/42 [==============================] - 0s 9ms/step - loss: 8.1709e-04
# Epoch 65/100
# 42/42 [==============================] - 0s 9ms/step - loss: 7.8456e-04
# Epoch 66/100
# 42/42 [==============================] - 0s 10ms/step - loss: 7.8808e-04
# Epoch 67/100
# 42/42 [==============================] - 0s 10ms/step - loss: 8.3121e-04
# Epoch 68/100
# 42/42 [==============================] - 0s 10ms/step - loss: 7.7895e-04
# Epoch 69/100
# 42/42 [==============================] - 0s 10ms/step - loss: 7.3182e-04
# Epoch 70/100
# 42/42 [==============================] - 0s 10ms/step - loss: 8.0505e-04
# Epoch 71/100
# 42/42 [==============================] - 0s 10ms/step - loss: 7.8651e-04
# Epoch 72/100
# 42/42 [==============================] - 0s 9ms/step - loss: 7.9627e-04
# Epoch 73/100
# 42/42 [==============================] - 0s 10ms/step - loss: 7.4376e-04
# Epoch 74/100
# 42/42 [==============================] - 0s 10ms/step - loss: 7.4871e-04
# Epoch 75/100
# 42/42 [==============================] - 0s 10ms/step - loss: 7.3156e-04
# Epoch 76/100
# 42/42 [==============================] - 0s 10ms/step - loss: 7.8729e-04
# Epoch 77/100
# 42/42 [==============================] - 0s 9ms/step - loss: 6.9479e-04
# Epoch 78/100
# 42/42 [==============================] - 0s 10ms/step - loss: 6.9830e-04
# Epoch 79/100
# 42/42 [==============================] - 0s 10ms/step - loss: 7.0256e-04
# Epoch 80/100
# 42/42 [==============================] - 0s 10ms/step - loss: 7.1321e-04
# Epoch 81/100
# 42/42 [==============================] - 0s 10ms/step - loss: 6.9286e-04
# Epoch 82/100
# 42/42 [==============================] - 0s 10ms/step - loss: 7.1896e-04
# Epoch 83/100
# 42/42 [==============================] - 0s 10ms/step - loss: 6.3892e-04
# Epoch 84/100
# 42/42 [==============================] - 0s 10ms/step - loss: 6.9512e-04
# Epoch 85/100
# 42/42 [==============================] - 0s 10ms/step - loss: 6.0574e-04
# Epoch 86/100
# 42/42 [==============================] - 0s 9ms/step - loss: 6.3474e-04
# Epoch 87/100
# 42/42 [==============================] - 0s 10ms/step - loss: 6.6157e-04
# Epoch 88/100
# 42/42 [==============================] - 0s 9ms/step - loss: 6.4804e-04
# Epoch 89/100
# 42/42 [==============================] - 0s 10ms/step - loss: 7.0970e-04
# Epoch 90/100
# 42/42 [==============================] - 0s 10ms/step - loss: 6.1051e-04
# Epoch 91/100
# 42/42 [==============================] - 0s 10ms/step - loss: 6.5901e-04
# Epoch 92/100
# 42/42 [==============================] - 0s 9ms/step - loss: 6.9730e-04
# Epoch 93/100
# 42/42 [==============================] - 0s 9ms/step - loss: 6.4879e-04
# Epoch 94/100
# 42/42 [==============================] - 0s 9ms/step - loss: 6.3693e-04
# Epoch 95/100
# 42/42 [==============================] - 0s 9ms/step - loss: 6.0201e-04
# Epoch 96/100
# 42/42 [==============================] - 0s 9ms/step - loss: 5.9705e-04
# Epoch 97/100
# 42/42 [==============================] - 0s 9ms/step - loss: 5.8185e-04
# Epoch 98/100
# 42/42 [==============================] - 0s 9ms/step - loss: 6.8422e-04
# Epoch 99/100
# 42/42 [==============================] - 0s 10ms/step - loss: 5.7314e-04
# Epoch 100/100
# 42/42 [==============================] - 0s 9ms/step - loss: 5.4738e-04

# %% [markdown]
# ## Testing the model

# %%
y_train_pred = scaler.inverse_transform(model.predict(X_train_sc))
y_test_pred  = scaler.inverse_transform(model.predict(X_test_sc ))

# %% [markdown]
# ### Mean Error

# %%
from sklearn.metrics import mean_squared_error, r2_score

train_error = mean_squared_error(y_train_pred, y_train, squared=False)
test_error  = mean_squared_error(y_test_pred , y_test , squared=False)

print(f'Mean Training Error:', round(train_error, 2))
print(f'Mean Testing  Error:', round(test_error , 2))

print(f'Train Accuracy: {round(100*r2_score(y_train_pred , y_train), 2)}%')
print(f'Test  Accuracy: {round(100*r2_score(y_test_pred  , y_test ), 2)}%')
# Out:
# Mean Training Error: 116.5
# Mean Testing  Error: 263.58
# Train Accuracy: 99.67%
# Test  Accuracy: 96.24%

# %% [markdown]
# ## Plotting Prediction vs Reality

# %% [markdown]
# ### Train Data

# %%
fig, ax = plt.subplots(figsize=(22, 6))

ax.plot(df_train[feature][window_len:].index, y_train, label='Reality')
ax.plot(df_train[feature][window_len:].index, y_train_pred, label='Prediction')

ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Bitcoin Price (USD)', fontsize=12)
ax.set_title('Reality vs Prediction - Closing Price of Bitcoin Train Data', fontsize=16)
ax.legend(fontsize=12)

# %% [markdown]
# ### Test Data

# %%
fig, ax = plt.subplots(figsize=(22, 6))


ax.plot(df_test[feature][window_len:].index, y_test, label='Reality')
ax.plot(df_test[feature][window_len:].index, y_test_pred, label='Prediction')

ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Bitcoin Price (USD)', fontsize=12)
ax.set_title('Reality vs Prediction - Closing Price of Bitcoin Test Data', fontsize=16)
ax.legend(fontsize=12)
